# %% [markdown]
# <a href="https://colab.research.google.com/github/giankev/lightweight-model-for-signal-processing/blob/main/syntethic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sionna tensorflow matplotlib torch
# Out:
# Requirement already satisfied: sionna in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: tensorflow in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: matplotlib in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: torch in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (2.10.0+cu130)
# Requirement already satisfied: sionna-rt==1.2.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna) (1.2.1)
# Requirement already satisfied: numpy<2.0,>=1.26 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna) (1.26.4)
# Requirement already satisfied: scipy>=1.14.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna) (1.17.1)
# Requirement already satisfied: importlib_resources>=6.4.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna) (6.5.2)
# Requirement already satisfied: mitsuba==3.7.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna-rt==1.2.1->sionna) (3.7.1)
# Requirement already satisfied: drjit==1.2.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna-rt==1.2.1->sionna) (1.2.0)
# Requirement already satisfied: ipywidgets>=8.1.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna-rt==1.2.1->sionna) (8.1.7)
# Requirement already satisfied: pythreejs>=2.4.2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna-rt==1.2.1->sionna) (2.4.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sionna-rt==1.2.1->sionna) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (1.78.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: filelock in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (3.24.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: cuda-bindings==13.0.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.96)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.85)
# Requirement already satisfied: nvidia-cudnn-cu13==9.15.1.9 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (9.15.1.9)
# Requirement already satisfied: nvidia-cublas==13.1.0.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.1.0.3)
# Requirement already satisfied: nvidia-cufft==12.0.0.61 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (12.0.0.61)
# Requirement already satisfied: nvidia-curand==10.4.0.35 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (12.6.3.3)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx==13.0.85 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.85)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (13.0.88)
# Requirement already satisfied: nvidia-cufile==1.15.1.6 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (1.15.1.6)
# Requirement already satisfied: triton==3.6.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from cuda-bindings==13.0.3->torch) (1.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: comm>=0.1.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.6.3)
# Requirement already satisfied: wcwidth in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.8.5)
# Requirement already satisfied: rich in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.7.0)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from pythreejs>=2.4.2->sionna-rt==1.2.1->sionna) (4.3.5)
# Requirement already satisfied: traittypes>=0.2.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from ipydatawidgets>=1.1.1->pythreejs>=2.4.2->sionna-rt==1.2.1->sionna) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (3.0.0)
# Requirement already satisfied: pure_eval in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.1.5->sionna-rt==1.2.1->sionna) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/leo/anaconda3/envs/radio/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
import numpy as np
import sionna
import os
import torch
import matplotlib.pyplot as plt
from dataclasses import dataclass
from sionna.phy.mapping import Constellation, Mapper
from sionna.phy.channel import AWGN

# Use dataclass for clean configuration
@dataclass(frozen=True)
class RadioSimConfig:
    """
    Configuration for 16-QAM Signal Generation.
    """
    num_examples: int = 20_000     # Training set size
    seq_length: int = 512          # Shorter sequences train faster (512 or 1024)
    bits_per_symbol: int = 4       # 16-QAM
    
    # SNR Range (dB)
    snr_db_min: float = 5.0        # Harder noise floor
    snr_db_max: float = 25.0       # Clean signals
    
    # Carrier Frequency Offset (CFO)
    # 0.1 rad/sample allows for multiple full rotations per frame
    max_cfo_rad: float = 0.1       
    
    # Random initial phase
    random_phase: bool = True
    
    seed: int = 42
# Out:
# 2026-02-26 15:38:55.906700: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-26 15:38:55.906966: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-26 15:38:55.942295: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-26 15:38:56.798414: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-26 15:38:56.798644: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
def complex_to_2ch_real(x: tf.Tensor) -> tf.Tensor:
    """Converts [N, L] complex to [N, 2, L] real (PyTorch format: Channels First)."""
    i = tf.math.real(x) # [N, L]
    q = tf.math.imag(x) # [N, L]
    # Stack to [N, 2, L]
    return tf.stack([i, q], axis=1)

def generate_enhanced_dataset(cfg: RadioSimConfig) -> dict:
    """
    Generates synthetic 16-QAM dataset with CFO and AWGN.
    """
    # 1. Setup
    rng = tf.random.Generator.from_seed(cfg.seed)
    constellation = Constellation("qam", cfg.bits_per_symbol)
    mapper = Mapper(constellation=constellation)
    awgn = AWGN()

    N, L = cfg.num_examples, cfg.seq_length
    
    print(f"Generating {N} samples of length {L}...")
    
    # 2. Bits & Symbols
    # Generate random bits
    num_bits = L * cfg.bits_per_symbol
    bits = rng.uniform([N, num_bits], minval=0, maxval=2, dtype=tf.int32)
    
    # Map to complex symbols [N, L]
    x_clean = mapper(bits) 

    # 3. Channel Impairments
    # A. Carrier Frequency Offset (Linear Drift)
    # Random drift per sample: +/- max_cfo_rad
    cfo_rad = rng.uniform([N, 1], minval=-cfg.max_cfo_rad, maxval=cfg.max_cfo_rad, dtype=tf.float32)
    
    # B. Phase Offset (Constant)
    if cfg.random_phase:
        phi_0 = rng.uniform([N, 1], minval=-np.pi, maxval=np.pi, dtype=tf.float32)
    else:
        phi_0 = tf.zeros([N, 1])

    # Time vector [1, L] -> 0, 1, 2...
    t = tf.range(L, dtype=tf.float32)[tf.newaxis, :]
    
    # Phase evolution: theta(t) = (omega * t) + phi_0
    phase_evolution = (cfo_rad * t) + phi_0
    
    # Apply rotation: x_rot = x * e^(j*theta)
    rot_vector = tf.complex(tf.math.cos(phase_evolution), tf.math.sin(phase_evolution))
    x_rotated = x_clean * rot_vector

    # C. AWGN Noise
    snr_db = rng.uniform([N, 1], minval=cfg.snr_db_min, maxval=cfg.snr_db_max, dtype=tf.float32)
    # Sionna AWGN takes noise variance (No), not SNR directly for complex signals.
    # Es = 1 (normalized constellation). SNR = Es / No => No = 1 / 10^(SNR/10)
    no = 1.0 / (10.0 ** (snr_db / 10.0))
    
    # Sionna's AWGN expects noise_power density or variance? 
    # Usually it takes 'noise_power' which matches variance for unit energy signals.
    y_noisy = awgn(x_rotated, no)

    # 4. Format Output
    # PyTorch usually expects [Batch, Channels, Time] -> [N, 2, L]
    iq_clean_real = complex_to_2ch_real(x_clean)
    iq_noisy_real = complex_to_2ch_real(y_noisy)

    return {
        "iq_noisy": iq_noisy_real.numpy().astype(np.float32),
        "iq_clean": iq_clean_real.numpy().astype(np.float32),
        "bits": bits.numpy().astype(np.uint8),
        "cfo_labels": cfo_rad.numpy().astype(np.float32),  # Target for NN
        "phase_labels": phi_0.numpy().astype(np.float32),
        "snr_db": snr_db.numpy().astype(np.float32).flatten()
    }

# %%
# Create Config
config = RadioSimConfig()

# Generate
data_dict = generate_enhanced_dataset(config)

# Convert dictionary of numpy arrays to dictionary of torch tensors
torch_data = {k: torch.from_numpy(v) for k, v in data_dict.items()}

# Save
output_path = "./data/radio_data.pth"
os.makedirs(os.path.dirname(output_path), exist_ok=True)
torch.save(torch_data, output_path)

print(f"\n[Success] Dataset saved to: {output_path}")
print(f"Shapes:")
print(f"  Input (Noisy): {torch_data['iq_noisy'].shape}  <- [N, 2, L]")
print(f"  Labels (CFO):  {torch_data['cfo_labels'].shape}")
print(f"  Bits:          {torch_data['bits'].shape}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772116739.103674    8394 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1772116739.114341    8394 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Generating 20000 samples of length 512...
#
# [Success] Dataset saved to: ./data/radio_data.pth
# Shapes:
#   Input (Noisy): torch.Size([20000, 2, 512])  <- [N, 2, L]
#   Labels (CFO):  torch.Size([20000, 1])
#   Bits:          torch.Size([20000, 2048])

# %%
def plot_example(idx, data):
    iq_n = data['iq_noisy'][idx]
    iq_c = data['iq_clean'][idx]
    cfo = data['cfo_labels'][idx].item()
    snr = data['snr_db'][idx].item()
    
    # Convert [2, L] -> Complex [L]
    z_n = iq_n[0] + 1j*iq_n[1]
    z_c = iq_c[0] + 1j*iq_c[1]
    
    plt.figure(figsize=(10, 4))
    
    # 1. Constellation
    plt.subplot(1, 2, 1)
    plt.title(f"Constellation (SNR={snr:.1f}dB, CFO={cfo:.4f})")
    plt.scatter(z_n.real, z_n.imag, s=1, alpha=0.5, label='Rx Noisy')
    plt.scatter(z_c.real, z_c.imag, s=5, c='k', marker='x', label='Tx Clean')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.axis('equal')
    
    # 2. Phase Track (To see the rotation)
    plt.subplot(1, 2, 2)
    plt.title("Phase Evolution over Time")
    plt.plot(np.angle(z_n), lw=0.5, alpha=0.8)
    plt.xlabel("Symbol Index")
    plt.ylabel("Phase (rad)")
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# Plot first 3 examples
print("Visualizing generated samples...")
for i in range(3):
    plot_example(i, torch_data)
# Out:
# Visualizing generated samples...
