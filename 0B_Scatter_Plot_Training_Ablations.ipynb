# %% [markdown]
# ### Scatter plot starved training ablation studies (8 symbols per pilot)

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# DATA DEFINITIONS
# ==========================================
ebno = np.arange(0, 13)

# 0. Classical Baseline
base_ber = [2.851e-01, 2.713e-01, 2.581e-01, 2.446e-01, 2.311e-01, 2.052e-01, 1.594e-01, 1.355e-01, 1.210e-01, 1.100e-01, 1.009e-01, 9.285e-02, 8.593e-02]
base_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.935e-01, 7.815e-01, 6.335e-01, 5.530e-01, 5.020e-01, 4.625e-01, 4.270e-01, 4.020e-01]

# 1. Full Training
full_ber = [2.670e-01, 2.502e-01, 2.336e-01, 2.163e-01, 1.951e-01, 1.477e-01, 2.846e-02, 9.071e-03, 7.418e-03, 6.653e-03, 6.397e-03, 6.092e-03, 6.066e-03]
full_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.915e-01, 3.500e-01, 4.300e-02, 2.450e-02, 1.950e-02, 1.650e-02, 1.600e-02, 1.500e-02]

# 2. Ablation 1: No Curriculum
a1_ber = [2.678e-01, 2.518e-01, 2.348e-01, 2.174e-01, 1.957e-01, 1.423e-01, 2.416e-02, 1.055e-02, 7.779e-03, 6.626e-03, 6.114e-03, 5.785e-03, 5.703e-03]
a1_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.900e-01, 2.855e-01, 4.650e-02, 2.850e-02, 2.400e-02, 2.000e-02, 1.650e-02, 1.450e-02]

# 3. Ablation 2: Static Aux Loss
a2_ber = [2.681e-01, 2.509e-01, 2.340e-01, 2.165e-01, 1.963e-01, 1.528e-01, 3.677e-02, 7.937e-03, 6.176e-03, 5.695e-03, 5.260e-03, 4.998e-03, 4.887e-03]
a2_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.930e-01, 4.365e-01, 4.550e-02, 1.550e-02, 1.400e-02, 1.150e-02, 1.100e-02, 1.050e-02]

# 4. Ablation 3: No Label Smoothing
a3_ber = [2.656e-01, 2.488e-01, 2.317e-01, 2.124e-01, 1.907e-01, 1.332e-01, 2.241e-02, 7.911e-03, 6.032e-03, 4.982e-03, 4.542e-03, 4.532e-03, 4.536e-03]
a3_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.795e-01, 2.940e-01, 3.900e-02, 2.400e-02, 1.650e-02, 1.250e-02, 1.150e-02, 1.150e-02]

# 5. Ablation 4: No Physics Loss
a4_ber = [2.664e-01, 2.488e-01, 2.312e-01, 2.125e-01, 1.900e-01, 1.275e-01, 1.846e-02, 1.088e-02, 8.660e-03, 7.930e-03, 7.379e-03, 7.028e-03, 6.732e-03]
a4_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.780e-01, 1.975e-01, 5.750e-02, 4.300e-02, 3.500e-02, 3.250e-02, 3.050e-02, 2.800e-02]

# 6. Ablation 5: Best Combined
a5_ber = [2.692e-01, 2.518e-01, 2.348e-01, 2.171e-01, 1.950e-01, 1.448e-01, 3.392e-02, 8.570e-03, 6.821e-03, 6.011e-03, 6.064e-03, 5.890e-03, 5.775e-03]
a5_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.875e-01, 4.185e-01, 4.100e-02, 2.050e-02, 1.700e-02, 1.450e-02, 1.350e-02, 1.350e-02]

# 7. Ablation 6: No Curric + Dyn Aux
a6_ber = [2.677e-01, 2.505e-01, 2.327e-01, 2.135e-01, 1.910e-01, 1.313e-01, 2.156e-02, 8.931e-03, 7.277e-03, 6.546e-03, 5.991e-03, 5.862e-03, 5.666e-03]
a6_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.770e-01, 2.835e-01, 3.900e-02, 2.750e-02, 2.250e-02, 1.800e-02, 1.750e-02, 1.600e-02]

# ==========================================
# RAINBOW COLORS
# ==========================================
c_base = 'black'
c_full = '#FF0000' # Red
c_a1   = '#FF7F00' # Orange
c_a2   = '#FFD700' # Yellow/Gold
c_a3   = '#00FF00' # Green
c_a4   = '#0000FF' # Blue
c_a5   = '#4B0082' # Indigo
c_a6   = '#9400D3' # Violet

# --- Plot 1: BER ---
plt.figure(figsize=(10, 6))
plt.semilogy(ebno, base_ber, 'o--', color=c_base, label='Baseline')
plt.semilogy(ebno, full_ber, 's-',  color=c_full, label='Full')
plt.semilogy(ebno, a1_ber,   '^-',  color=c_a1,   label='No Curric')
plt.semilogy(ebno, a2_ber,   'd-',  color=c_a2,   label='Static Aux')
plt.semilogy(ebno, a3_ber,   'v-',  color=c_a3,   label='No Smooth')
plt.semilogy(ebno, a4_ber,   'x-',  color=c_a4,   label='No Physics')
plt.semilogy(ebno, a5_ber,   '*-',  color=c_a5,   label='Combined')
plt.semilogy(ebno, a6_ber,   'p-',  color=c_a6,   label='No Curric+Dyn')
plt.title("BER Performance")
plt.xlabel("Eb/N0 (dB)")
plt.ylabel("BER")
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend(loc='lower left')
plt.show()

# --- Plot 2: BLER ---
plt.figure(figsize=(10, 6))
plt.semilogy(ebno, base_bler, 'o--', color=c_base, label='Baseline')
plt.semilogy(ebno, full_bler, 's-',  color=c_full, label='Full')
plt.semilogy(ebno, a1_bler,   '^-',  color=c_a1,   label='No Curric')
plt.semilogy(ebno, a2_bler,   'd-',  color=c_a2,   label='Static Aux')
plt.semilogy(ebno, a3_bler,   'v-',  color=c_a3,   label='No Smooth')
plt.semilogy(ebno, a4_bler,   'x-',  color=c_a4,   label='No Physics')
plt.semilogy(ebno, a5_bler,   '*-',  color=c_a5,   label='Combined')
plt.semilogy(ebno, a6_bler,   'p-',  color=c_a6,   label='No Curric+Dyn')
plt.title("BLER Performance")
plt.xlabel("Eb/N0 (dB)")
plt.ylabel("BLER")
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend(loc='lower left')
plt.show()

# --- Plot 3: Relative Difference (%) Ablation 2 vs Ablation 3 ---
# Difference = (A2 - A3) / A3 * 100
# Negative means Ablation 2 is better, Positive means Ablation 3 is better
ber_diff = [(a2 - a3)/a3 * 100 for a2, a3 in zip(a2_ber, a3_ber)]
bler_diff = []
for a2, a3 in zip(a2_bler, a3_bler):
    if a3 == 1.0 and a2 == 1.0: bler_diff.append(0.0)
    else: bler_diff.append((a2 - a3)/a3 * 100)

plt.figure(figsize=(10, 6))
plt.plot(ebno, ber_diff,  'o-', color='#3498db', label='BER Delta (A2 vs A3)')
plt.plot(ebno, bler_diff, 's-', color='#e74c3c', label='BLER Delta (A2 vs A3)')
plt.axhline(0, color='black', linestyle='--')
plt.title("Relative Performance: Static Aux (A2) vs No Smoothing (A3)")
plt.xlabel("Eb/N0 (dB)")
plt.ylabel("Relative Difference (%)")
plt.grid(True, ls="--", alpha=0.5)
plt.legend(loc='lower left')
plt.show()
