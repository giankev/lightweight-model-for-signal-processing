# %% [markdown]
# ### Scatter plot starved training ablation studies (8 symbols per pilot)

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# HARDCODED CONSTANTS: ABLATION STUDIES
# ==========================================
ebno = np.arange(0, 13)

# 0. Classical Baseline
base_ber = [2.851e-01, 2.713e-01, 2.581e-01, 2.446e-01, 2.311e-01, 2.052e-01, 1.594e-01, 1.355e-01, 1.210e-01, 1.100e-01, 1.009e-01, 9.285e-02, 8.593e-02]
base_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.935e-01, 7.815e-01, 6.335e-01, 5.530e-01, 5.020e-01, 4.625e-01, 4.270e-01, 4.020e-01]

# 1. Full Training (Original)
full_ber = [2.670e-01, 2.502e-01, 2.336e-01, 2.163e-01, 1.951e-01, 1.477e-01, 2.846e-02, 9.071e-03, 7.418e-03, 6.653e-03, 6.397e-03, 6.092e-03, 6.066e-03]
full_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.915e-01, 3.500e-01, 4.300e-02, 2.450e-02, 1.950e-02, 1.650e-02, 1.600e-02, 1.500e-02]

# 2. Ablation 1: No Curriculum
a1_ber = [2.678e-01, 2.518e-01, 2.348e-01, 2.174e-01, 1.957e-01, 1.423e-01, 2.416e-02, 1.055e-02, 7.779e-03, 6.626e-03, 6.114e-03, 5.785e-03, 5.703e-03]
a1_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.900e-01, 2.855e-01, 4.650e-02, 2.850e-02, 2.400e-02, 2.000e-02, 1.650e-02, 1.450e-02]

# 3. Ablation 2: Static Aux Loss (Winner)
a2_ber = [2.681e-01, 2.509e-01, 2.340e-01, 2.165e-01, 1.963e-01, 1.528e-01, 3.677e-02, 7.937e-03, 6.176e-03, 5.695e-03, 5.260e-03, 4.998e-03, 4.887e-03]
a2_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.930e-01, 4.365e-01, 4.550e-02, 1.550e-02, 1.400e-02, 1.150e-02, 1.100e-02, 1.050e-02]

# 4. Ablation 3: No Label Smoothing
a3_ber = [2.656e-01, 2.488e-01, 2.317e-01, 2.124e-01, 1.907e-01, 1.332e-01, 2.241e-02, 7.911e-03, 6.032e-03, 4.982e-03, 4.542e-03, 4.532e-03, 4.536e-03]
a3_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.795e-01, 2.940e-01, 3.900e-02, 2.400e-02, 1.650e-02, 1.250e-02, 1.150e-02, 1.150e-02]

# 5. Ablation 4: No Physics Loss (Black Box)
a4_ber = [2.664e-01, 2.488e-01, 2.312e-01, 2.125e-01, 1.900e-01, 1.275e-01, 1.846e-02, 1.088e-02, 8.660e-03, 7.930e-03, 7.379e-03, 7.028e-03, 6.732e-03]
a4_bler = [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 9.780e-01, 1.975e-01, 5.750e-02, 4.300e-02, 3.500e-02, 3.250e-02, 3.050e-02, 2.800e-02]

# ==========================================
# PLOTTING
# ==========================================
c_base = 'gray'
c_full = '#2ecc71' # Green
c_a1 = '#3498db'   # Blue
c_a2 = '#9b59b6'   # Purple
c_a3 = '#e67e22'   # Orange
c_a4 = '#e74c3c'   # Red

# --- Plot 1: BER ---
plt.figure(figsize=(10, 7))
plt.semilogy(ebno, base_ber, marker='o', linestyle='--', color=c_base, linewidth=2, label='Classical Baseline')
plt.semilogy(ebno, full_ber, marker='s', linestyle='-', color=c_full, linewidth=3, markersize=8, label='Full Training (Original)')
plt.semilogy(ebno, a1_ber, marker='^', linestyle='-', color=c_a1, linewidth=2, label='Ablation 1: No Curriculum')
plt.semilogy(ebno, a2_ber, marker='d', linestyle='-', color=c_a2, linewidth=2.5, markersize=7, label='Ablation 2: Static Aux Loss')
plt.semilogy(ebno, a3_ber, marker='v', linestyle='-', color=c_a3, linewidth=2, label='Ablation 3: No Label Smoothing')
plt.semilogy(ebno, a4_ber, marker='x', linestyle='-', color=c_a4, linewidth=2, label='Ablation 4: No Physics Loss')

plt.title("Ablation Studies: Post-FEC Bit Error Rate (BER)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Eb/N0 (dB)", fontsize=13)
plt.ylabel("BER", fontsize=13)
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.xlim(0, 12)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# --- Plot 2: BLER ---
plt.figure(figsize=(10, 7))
plt.semilogy(ebno, base_bler, marker='o', linestyle='--', color=c_base, linewidth=2, label='Classical Baseline')
plt.semilogy(ebno, full_bler, marker='s', linestyle='-', color=c_full, linewidth=3, markersize=8, label='Full Training (Original)')
plt.semilogy(ebno, a1_bler, marker='^', linestyle='-', color=c_a1, linewidth=2, label='Ablation 1: No Curriculum')
plt.semilogy(ebno, a2_bler, marker='d', linestyle='-', color=c_a2, linewidth=2.5, markersize=7, label='Ablation 2: Static Aux Loss')
plt.semilogy(ebno, a3_bler, marker='v', linestyle='-', color=c_a3, linewidth=2, label='Ablation 3: No Label Smoothing')
plt.semilogy(ebno, a4_bler, marker='x', linestyle='-', color=c_a4, linewidth=2, label='Ablation 4: No Physics Loss')

plt.title("Ablation Studies: Block Error Rate (BLER)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Eb/N0 (dB)", fontsize=13)
plt.ylabel("BLER", fontsize=13)
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.xlim(0, 12)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
